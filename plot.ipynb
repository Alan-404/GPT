# %%
import torch
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %%
checkpoint = torch.load('./saved_models/gpt.pt', map_location='cpu')

# %%
checkpoint['bleu']
# Out:
# [0.8174097907635723,
#  0.8552487615881295,
#  0.8354576826095581,
#  0.8404527286003376,
#  0.8858773071190407,
#  0.8911751652586049,
#  0.8763095654290298,
#  0.8845691084861755,
#  0.8849835806879504,
#  0.8887886610524408]

# %%
checkpoint['loss']
# Out:
# [1.4283343173306564,
#  0.7495353735726455,
#  1.1269791598977714,
#  0.9058365677965099,
#  0.6781185207695797,
#  0.5400607061797175,
#  0.7214553520597261,
#  0.5853496337759083,
#  0.6856390484448137,
#  0.579402048012306]

# %%
checkpoint['val_bleu']
# Out:
# [0.8607976498274967,
#  0.8566772429079845,
#  0.8710140385504427,
#  0.8726071720493251,
#  0.8622926196147656,
#  0.8620674245316406,
#  0.8678137346588332,
#  0.8678969807665924,
#  0.8666251949195204,
#  0.867522809526016]

# %%
plt.plot(checkpoint['loss'], label='Train Loss')
plt.plot(checkpoint['val_loss'], label='Validate Loss')
plt.legend()

# %%
plt.plot(checkpoint['metric'], label='Train BLEU Score')
plt.plot(checkpoint['val_metric'], label='Validate BLEU Score')
plt.legend()

# %%
checkpoint['epoch']
# Out:
# 20

# %%
len(checkpoint['loss'])
# Out:
# 20

# %%
len(checkpoint['val_loss'])
# Out:
# 15
